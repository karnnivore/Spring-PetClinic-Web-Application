# %%
def display_message():
    while True:
        print("Press Ctrl+C to stop!")

# %%
display_message()
# Out:
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# ...

# %%
def display_message():
    print("Press Ctrl+C to stop!")
    display_message()

# %%
display_message()
# Out:
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# Press Ctrl+C to stop!
# ...

# %%
print("Hi")
# Out:
# Hi
