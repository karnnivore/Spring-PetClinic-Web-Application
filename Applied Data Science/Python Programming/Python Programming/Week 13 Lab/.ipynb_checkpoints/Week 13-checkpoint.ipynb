# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = "myfile.txt"
line = "Hello there"
line = line + "\n" + "From A File"
line = line + "\n" + "This is Line 3"

# %%
line
# Out:
# 'Hello there\nFrom A File\nThis is Line 3'

# %%
with open(file, 'w') as my_file:
    my_file.write(line)

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Hello there
# From A File
# This is Line 3

# %%
file = "myfile.txt"

# %%
# filestream_1 = open(file, 'r')

# %%
# filestream_2 = open(file, 'w')

# %%
# filestream_3 = open(file, 'a')

# %%
# filestream_4 = open(file, 'r+')

# %%
# filestream_5 = open(file, 'w+')

# %%
# filestream_6 = open(file, 'a+')

# %%
# filestream_6.close()

# %%
# filestream_5.close()

# %%
# filestream_4.close()

# %%
# filestream_3.close()

# %%
# filestream_2.close()

# %%
# filestream_1.close()

# %%
with open(file, 'r') as my_file_stream:
    print("Statements with file", str(my_file_stream))
print("Statements outside the file")
# Out:
# Statements with file <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>
# Statements outside the file

# %%
file = "myfile.txt"

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
    print("Data type of <content> variable is", type(content))
# Out:
# Hello there
# From A File
# This is Line 3
# Data type of <content> variable is <class 'str'>

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Hello there
# From A File
# This is Line 3

# %%
filestream = open(file, 'r')
content = filestream.read()
print(content)
filestream.close()
# Out:
# Hello there
# From A File
# This is Line 3

# %%
with open(file, 'r') as my_file:
    print("First line is:", my_file.readline())
    print("Second line is:", my_file.readline())
    print("Third line is:", my_file.readline())
    print("Fourth line does not exist!", my_file.readline())
# Out:
# First line is: Hello there
#
# Second line is: From A File
#
# Third line is: This is Line 3
# Fourth line does not exist!

# %%
with open(file, 'r') as my_file:
    while True:
        line = my_file.readline()
        if len(line) > 0:
            print(line, end='')
        else:
            break
# Out:
# Hello there
# From A File
# This is Line 3

# %%
filestream = open(file, 'r')
while True:
    line = filestream.readline()
    if len(line) > 0:
        print(line, end='')
    else:
        break
filestream.close()
# Out:
# Hello there
# From A File
# This is Line 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open(file, 'r') as my_file:
    lines = my_file.readlines()
    for current_line in lines:
        print(current_line, end='')
# Out:
# Hello there
# From A File
# This is Line 3

# %%
filestream = open(file, 'r')
lines = filestream.readlines()
for current_line in lines:
    print(current_line, end='')
filestream.close()
# Out:
# Hello there
# From A File
# This is Line 3

# %%
file = "myfile.txt"

# %%
line = "This line will be the new content"

# %%
with open(file, 'w') as my_file:
    my_file.write(line)

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# This line will be the new content

# %%
line = "SECOND TRY: This line will be the new content"

# %%
filestream = open(file, 'w')
filestream.write(line)
filestream.close()

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# SECOND TRY: This line will be the new content

# %%
line= "\n" + "This line will be appended"

# %%
with open(file, 'a') as my_file:
    my_file.write(line)

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# SECOND TRY: This line will be the new content
# This line will be appended

# %%
line = "\n" + "Also, this lie will be appended"

# %%
filestream = open(file, 'a')
filestream.write(line)
filestream.close()

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# SECOND TRY: This line will be the new content
# This line will be appended
# Also, this lie will be appended

# %%
lines = ["New Line Content 1" + "\n",
         "New Line Content 2" + "\n",
        "Third New Line Content"]

# %%
with open(file, 'w') as my_file:
    my_file.writelines(lines)

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# New Line Content 1
# New Line Content 2
# Third New Line Content

# %%
lines = ["Ver 2.0 New Line Content 1" + "\n",
         "Ver 2.0 New Line Content 2" + "\n",
        "Ver 2.0 Third New Line Content"]

# %%
filestream = open(file, 'w')
filestream.writelines(lines)
filestream.close()

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Ver 2.0 New Line Content 1
# Ver 2.0 New Line Content 2
# Ver 2.0 Third New Line Content

# %%
lines = ["\n"+"Fist appended line" + "\n",
         "Appended Line 2 added" + "\n",
        "Appended Third and last line"]

# %%
with open(file, 'a') as my_file:
    my_file.writelines(lines)

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Ver 2.0 New Line Content 1
# Ver 2.0 New Line Content 2
# Ver 2.0 Third New Line Content
# Fist appended line
# Appended Line 2 added
# Appended Third and last line

# %%
lines = ["\n"+" Ver 3.0 Fist appended line" + "\n",
         "Ver 3.0 Line 2 added" + "\n",
        "Ver 3.0 Third and last line"]

# %%
filestream = open(file, 'a')
filestream.writelines(lines)
filestream.close()

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Ver 2.0 New Line Content 1
# Ver 2.0 New Line Content 2
# Ver 2.0 Third New Line Content
# Fist appended line
# Appended Line 2 added
# Appended Third and last line
#  Ver 3.0 Fist appended line
# Ver 3.0 Line 2 added
# Ver 3.0 Third and last line

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = "myfile.txt"

# %%
chars_to_skip = 4

# %%
with open(file, 'r') as my_file:
    my_file.seek(chars_to_skip)
    print("The 5th character is of the file is", my_file.read()[0])
# Out:
# The 5th character is of the file is 2

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Ver 2.0 New Line Content 1
# Ver 2.0 New Line Content 2
# Ver 2.0 Third New Line Content
# Fist appended line
# Appended Line 2 added
# Appended Third and last line
#  Ver 3.0 Fist appended line
# Ver 3.0 Line 2 added
# Ver 3.0 Third and last line

# %%
chars_to_skip = 4

# %%
filestream = open(file, 'r')
filestream.seek(chars_to_skip)
print("The 5th character is of the file is", filestream.read()[0])
filestream.close()
# Out:
# The 5th character is of the file is 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open(file, 'r') as my_file:
    my_file.seek(0)

# %% [markdown]
# OR

# %%
filestream = open(file, 'r')
filestream.seek(0)
filestream.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open(file, 'r') as my_file:
    my_file.readline()
    print(my_file.readline())
    position = my_file.tell()
    my_file.seek(0)
    my_file.seek(position)
    print(my_file.readline())
# Out:
# Ver 2.0 New Line Content 2
#
# Ver 2.0 Third New Line Content

# %%
with open(file, 'r') as my_file:
    content = my_file.read()
    print(content)
# Out:
# Ver 2.0 New Line Content 1
# Ver 2.0 New Line Content 2
# Ver 2.0 Third New Line Content
# Fist appended line
# Appended Line 2 added
# Appended Third and last line
#  Ver 3.0 Fist appended line
# Ver 3.0 Line 2 added
# Ver 3.0 Third and last line

# %%
filestream = open(file, 'r')
filestream.readline()
print(filestream.readline())
position = filestream.tell()
filestream.seek(0)
filestream.seek(position)
print(filestream.readline())
filestream.close()
# Out:
# Ver 2.0 New Line Content 2
#
# Ver 2.0 Third New Line Content

# %%
import csv

# %%
file = 'csvfile.csv'

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = John
# Row 1 Column 2 = Doe
# Row 1 Column 3 = 18
# Row 1 Column 4 = 987
# Row 2 Data:
# Row 2 Column 1 = Jane
# Row 2 Column 2 = Dow
# Row 2 Column 3 = 19
# Row 2 Column 4 = 654

# %%
filestream = open(file, 'r')
reader = csv.reader(filestream)
rowCount = 0
for row in reader:
    rowCount +=1
    print("Row", rowCount,"Data:")
    columnCount=0
    for column in row:
        columnCount +=1
        print("Row", rowCount, "Column", columnCount, "=", column)
filestream.close()
# Out:
# Row 1 Data:
# Row 1 Column 1 = John
# Row 1 Column 2 = Doe
# Row 1 Column 3 = 18
# Row 1 Column 4 = 987
# Row 2 Data:
# Row 2 Column 1 = Jane
# Row 2 Column 2 = Dow
# Row 2 Column 3 = 19
# Row 2 Column 4 = 654

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# https://docs.python.org/3/library/csv.html

# %%
# https://realpython.com/python-csv/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file, delimiter=',', quotechar='`', quoting=csv.QUOTE_MINIMAL)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = John
# Row 1 Column 2 = Doe
# Row 1 Column 3 = 18
# Row 1 Column 4 = 987
# Row 2 Data:
# Row 2 Column 1 = Jane
# Row 2 Column 2 = Dow
# Row 2 Column 3 = 19
# Row 2 Column 4 = 654

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file, delimiter=",", quotechar="'", quoting=csv.QUOTE_ALL)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = John
# Row 1 Column 2 = Doe
# Row 1 Column 3 = 18
# Row 1 Column 4 = 987
# Row 2 Data:
# Row 2 Column 1 = Jane
# Row 2 Column 2 = Dow
# Row 2 Column 3 = 19
# Row 2 Column 4 = 654

# %%
filestream = open(file, 'r')
reader = csv.reader(filestream, delimiter=',', quotechar='`', quoting=csv.QUOTE_MINIMAL)
rowCount = 0
for row in reader:
    rowCount +=1
    print("Row", rowCount,"Data:")
    columnCount=0
    for column in row:
        columnCount +=1
        print("Row", rowCount, "Column", columnCount, "=", column)
filestream.close()
# Out:
# Row 1 Data:
# Row 1 Column 1 = John
# Row 1 Column 2 = Doe
# Row 1 Column 3 = 18
# Row 1 Column 4 = 987
# Row 2 Data:
# Row 2 Column 1 = Jane
# Row 2 Column 2 = Dow
# Row 2 Column 3 = 19
# Row 2 Column 4 = 654

# %%
with open(file, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# John,Doe,18,987
# Jane,Dow,19,654

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow(['John Smith', 'Accounting', 'November'])
    employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

# %%
file = 'newcsvfile.csv'

# %%
data = [['new', 'row', 20, 543], ['boo', 'hoo', 21, 432]]

# %%
with open(file, 'a') as my_file:
    writer = csv.writer(my_file, lineterminator='\n')
    for row in data:
        writer.writerow(row)

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = new
# Row 1 Column 2 = row
# Row 1 Column 3 = 20
# Row 1 Column 4 = 543
# Row 2 Data:
# Row 2 Column 1 = boo
# Row 2 Column 2 = hoo
# Row 2 Column 3 = 21
# Row 2 Column 4 = 432
# Row 3 Data:
# Row 3 Column 1 = new
# Row 3 Column 2 = row
# Row 3 Column 3 = 20
# Row 3 Column 4 = 543
# Row 4 Data:
# Row 4 Column 1 = boo
# Row 4 Column 2 = hoo
# Row 4 Column 3 = 21
# Row 4 Column 4 = 432
# Row 5 Data:
# Row 5 Column 1 = new
# Row 5 Column 2 = row
# Row 5 Column 3 = 20
# Row 5 Column 4 = 543
# Row 6 Data:
# Row 6 Column 1 = boo
# Row 6 Column 2 = hoo
# Row 6 Column 3 = 21
# Row 6 Column 4 = 432

# %%
file = 'secondNewcsvfile.csv'

# %%
data = [['new', 'row', 2000, 54300], ['boo', 'hoo', 2100, 43200]]

# %%
filestream = open(file, 'a')
writer = csv.writer(filestream, lineterminator='\n')
for row in data:
    writer.writerow(row)
filestream.close()

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = new
# Row 1 Column 2 = row
# Row 1 Column 3 = 2000
# Row 1 Column 4 = 54300
# Row 2 Data:
# Row 2 Column 1 = boo
# Row 2 Column 2 = hoo
# Row 2 Column 3 = 2100
# Row 2 Column 4 = 43200
# Row 3 Data:
# Row 3 Column 1 = new
# Row 3 Column 2 = row
# Row 3 Column 3 = 2000
# Row 3 Column 4 = 54300
# Row 4 Data:
# Row 4 Column 1 = boo
# Row 4 Column 2 = hoo
# Row 4 Column 3 = 2100
# Row 4 Column 4 = 43200
# Row 5 Data:
# Row 5 Column 1 = new
# Row 5 Column 2 = row
# Row 5 Column 3 = 2000
# Row 5 Column 4 = 54300
# Row 6 Data:
# Row 6 Column 1 = boo
# Row 6 Column 2 = hoo
# Row 6 Column 3 = 2100
# Row 6 Column 4 = 43200
# Row 7 Data:
# Row 7 Column 1 = new
# Row 7 Column 2 = row
# Row 7 Column 3 = 2000
# Row 7 Column 4 = 54300
# Row 8 Data:
# Row 8 Column 1 = boo
# Row 8 Column 2 = hoo
# Row 8 Column 3 = 2100
# Row 8 Column 4 = 43200
# Row 9 Data:
# Row 9 Column 1 = new
# Row 9 Column 2 = row
# Row 9 Column 3 = 2000
# Row 9 Column 4 = 54300
# Row 10 Data:
# Row 10 Column 1 = boo
# Row 10 Column 2 = hoo
# Row 10 Column 3 = 2100
# Row 10 Column 4 = 43200

# %%
filestream = open(file, 'a')
writer = csv.writer(filestream, lineterminator='\n')
for row in data:
    writer.writerow(row)
filestream.close()

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = new
# Row 1 Column 2 = row
# Row 1 Column 3 = 2000
# Row 1 Column 4 = 54300
# Row 2 Data:
# Row 2 Column 1 = boo
# Row 2 Column 2 = hoo
# Row 2 Column 3 = 2100
# Row 2 Column 4 = 43200
# Row 3 Data:
# Row 3 Column 1 = new
# Row 3 Column 2 = row
# Row 3 Column 3 = 2000
# Row 3 Column 4 = 54300
# Row 4 Data:
# Row 4 Column 1 = boo
# Row 4 Column 2 = hoo
# Row 4 Column 3 = 2100
# Row 4 Column 4 = 43200
# Row 5 Data:
# Row 5 Column 1 = new
# Row 5 Column 2 = row
# Row 5 Column 3 = 2000
# Row 5 Column 4 = 54300
# Row 6 Data:
# Row 6 Column 1 = boo
# Row 6 Column 2 = hoo
# Row 6 Column 3 = 2100
# Row 6 Column 4 = 43200
# Row 7 Data:
# Row 7 Column 1 = new
# Row 7 Column 2 = row
# Row 7 Column 3 = 2000
# Row 7 Column 4 = 54300
# Row 8 Data:
# Row 8 Column 1 = boo
# Row 8 Column 2 = hoo
# Row 8 Column 3 = 2100
# Row 8 Column 4 = 43200
# Row 9 Data:
# Row 9 Column 1 = new
# Row 9 Column 2 = row
# Row 9 Column 3 = 2000
# Row 9 Column 4 = 54300
# Row 10 Data:
# Row 10 Column 1 = boo
# Row 10 Column 2 = hoo
# Row 10 Column 3 = 2100
# Row 10 Column 4 = 43200
# Row 11 Data:
# Row 11 Column 1 = new
# Row 11 Column 2 = row
# Row 11 Column 3 = 2000
# Row 11 Column 4 = 54300
# Row 12 Data:
# Row 12 Column 1 = boo
# Row 12 Column 2 = hoo
# Row 12 Column 3 = 2100
# Row 12 Column 4 = 43200

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = 'writerowscsvfile.csv'

# %%
data = [['new', 'row', 2222, 54322], ['boo', 'hoo', 2122, 43222]]

# %%
with open(file, 'a') as my_file:
    writer = csv.writer(my_file, lineterminator='\n')
    writer.writerows(data)

# %%
with open(file, 'r') as my_file:
    reader = csv.reader(my_file)
    rowCount = 0
    for row in reader:
        rowCount +=1
        print("Row", rowCount,"Data:")
        columnCount=0
        for column in row:
            columnCount +=1
            print("Row", rowCount, "Column", columnCount, "=", column)
# Out:
# Row 1 Data:
# Row 1 Column 1 = new
# Row 1 Column 2 = row
# Row 1 Column 3 = 2222
# Row 1 Column 4 = 54322
# Row 2 Data:
# Row 2 Column 1 = boo
# Row 2 Column 2 = hoo
# Row 2 Column 3 = 2122
# Row 2 Column 4 = 43222
# Row 3 Data:
# Row 3 Column 1 = new
# Row 3 Column 2 = row
# Row 3 Column 3 = 2222
# Row 3 Column 4 = 54322
# Row 4 Data:
# Row 4 Column 1 = boo
# Row 4 Column 2 = hoo
# Row 4 Column 3 = 2122
# Row 4 Column 4 = 43222
# Row 5 Data:
# Row 5 Column 1 = new
# Row 5 Column 2 = row
# Row 5 Column 3 = 2222
# Row 5 Column 4 = 54322
# Row 6 Data:
# Row 6 Column 1 = boo
# Row 6 Column 2 = hoo
# Row 6 Column 3 = 2122
# Row 6 Column 4 = 43222

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = 'csvfile_dict.csv'

# %%
fieldnames = ['first_name', 'last_name', 'age', 'num']

# %%
data = {
    'first_name': 'Jack',
    'last_name': 'Hot',
    'age':45,
    'num':834
}

# %%
with open(file, 'a') as my_file:
    writer = csv.DictWriter(my_file, fieldnames=fieldnames, lineterminator='\n')
    writer.writeheader()
    writer.writerow(data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = "csvfile_multi.csv"

# %%
data_1 = {
    'first_name':"John",
    'last_name':"Smith",
    'age':41,
    'num':234
}

# %%
data_2 = {
    'first_name':"Jane",
    'last_name':"Dice",
    'age':47,
    'num':382
}

# %%
combined = [data_1, data_2]

# %%
with open(file, 'a') as my_file:
    writer = csv.DictWriter(my_file, fieldnames=data_1.keys(), lineterminator='\n')
    writer.writeheader()
    writer.writerow(combined)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-2b2f46e2d86d> in <module>
#       2     writer = csv.DictWriter(my_file, fieldnames=data_1.keys(), lineterminator='\n')
#       3     writer.writeheader()
# ----> 4     writer.writerow(combined)
#
# C:\ProgramData\Anaconda3\lib\csv.py in writerow(self, rowdict)
#     153
#     154     def writerow(self, rowdict):
# --> 155         return self.writer.writerow(self._dict_to_list(rowdict))
#     156
#     157     def writerows(self, rowdicts):
#
# C:\ProgramData\Anaconda3\lib\csv.py in _dict_to_list(self, rowdict)
#     146     def _dict_to_list(self, rowdict):
#     147         if self.extrasaction == "raise":
# --> 148             wrong_fields = rowdict.keys() - self.fieldnames
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
with open(file, 'a') as my_file:
    writer = csv.DictWriter(my_file, fieldnames=data_1.keys(), lineterminator='\n')
    writer.writeheader()
    writer.writerows(combined)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = 'csvfile_dict.csv'

# %%
with open(file, 'r') as my_file:
    reader = csv.DictReader(my_file)
    for row in reader:
        for column in row:
            print(row[column], end=' ')
        print()
# Out:
# Jack Hot 45 834
# first_name last_name age num
# Jack Hot 45 834
# first_name last_name age num
# Jack Hot 45 834

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open(file, 'r') as my_file:
    reader = csv.DictReader(my_file)
    for row in reader:
        print(row['first_name'], row['last_name'], row['age'], row['num'])
        print()
# Out:
# Jack Hot 45 834
#
# first_name last_name age num
#
# Jack Hot 45 834
#
# first_name last_name age num
#
# Jack Hot 45 834

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = 'csvfile_dict.csv'

# %%
fieldnames = ['first_name', 'last_name', 'age', 'num']

# %%
with open(file, 'r') as my_file:
    reader = csv.DictReader(my_file, fieldnames=fieldnames)
    for row in reader:
        for column in fieldnames:
            print(row[column], end=' ')
        print()
# Out:
# first_name last_name age num
# Jack Hot 45 834
# first_name last_name age num
# Jack Hot 45 834
# first_name last_name age num
# Jack Hot 45 834

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pickle

# %%
file = 'myfile.bin'

# %%
string_data = "Hello from Reza!!!"

# %%
with open(file, 'wb') as my_file:
    pickle.dump(string_data, my_file)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = 'myfile.bin'

# %%
with open(file, 'rb') as my_file:
    content = pickle.load(my_file)
    print(content)
# Out:
# Hello from Reza!!!
