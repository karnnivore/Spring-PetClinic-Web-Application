# %% [markdown]
# # The Python code for a Test Scores program

# %%
counter = 0
score_total = 0
test_score = 0

# %%
while test_score != 999:
    test_score = int(input("Enter test score: "))
    if test_score >= 0 and test_score <= 100:
        score_total += test_score
        counter += 1
# Out:
# Enter test score: 22
# Enter test score: 222
# Enter test score: 3333
# Enter test score: 9999
# Enter test score: 999

# %%
average_score = round(score_total / counter)

# %%
print("Total Score: " + str(score_total))
# Out:
# Total Score: 22

# %%
print("Average Score: " + str(average_score))
# Out:
# Average Score: 22

# %%
average_score = round(score_total / counter,2)
print("Average Score: " + str(average_score))
# Out:
# Average Score: 22.0

# %% [markdown]
# ## An indentation error

# %%
print("Total Score: " + str(score_total))
 print("Average Score: " + str(average_score))
# Out:
#   File "<ipython-input-7-e41d85a5b377>", line 2
#     print("Average Score: " + str(average_score))
#     ^
# IndentationError: unexpected indent

# %%
print("Total Score: " + str(score_total))
print("Average Score: " + str(average_score))
# Out:
# Total Score: 22
# Average Score: 22.0

# %% [markdown]
# ## The Test Scores program with comments (part 1)

# %%
# This is a tutorial program that illustrates the use of 
# the while and if statements
# initialize variables
counter = 0
score_total = 0
test_score = 0
# get scores
while test_score != 999:
    test_score = int(input("Enter test score: "))
    if test_score >= 0 and test_score <= 100:
        score_total += test_score    # add score to total
        counter += 1                 # add 1 to counter
# calculate average score
#average_score = score_total / counter
#average_score = round(average_score)
average_score = round(       # implicit continuation
    score_total / counter) 	  # same results as 
                             # commented out statements
# display the result
print("======================")
print("Total Score: " + str(score_total) # implicit cont.
      + "\nAverage Score: " + str(average_score))
# Out:
# Enter test score: 22
# Enter test score: 33
# Enter test score: 66
# Enter test score: 999
# ======================
# Total Score: 121
# Average Score: 40

# %%
## Three Python data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Examples with two operands

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The order of precedence

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The most useful compound assignment operators

# %%
counter = 0
counter = counter + 1      # counter = 1

# %%
counter
# Out:
# 1

# %%
counter += 1      # counter = 2

# %%
counter
# Out:
# 2

# %%
score_total = 0            # score_total = 0

# %%
score_total += 70          # score_total = 70

# %%
score_total
# Out:
# 70

# %%
score_total += 80          # score_total = 150

# %%
score_total
# Out:
# 150

# %%
total = 1000.0
total += 100.0

# %%
total
# Out:
# 1100.0

# %%
counter = 10
counter -= 1

# %%
counter
# Out:
# 9

# %%
price = 100
price *= .8

# %%
price
# Out:
# 80.0

# %% [markdown]
# ## A floating-point result that isn’t precise

# %%
subtotal = 74.95               # subtotal = 74.95
tax = subtotal * .1

# %%
tax
# Out:
# 7.495000000000001

# %% [markdown]
# ## The solution is as follows:

# %%
subtotal = 74.95               # subtotal = 74.95
tax = round(subtotal * .1,2)

# %%
tax
# Out:
# 7.5

# %% [markdown]
# ## The str() function

# %%
name = "Bob Smith"

# %%
name = "Bob Smith"
age = 40

# %%
message = name + " is " + str(age) + " years old."

# %%
message
# Out:
# 'Bob Smith is 40 years old.'

# %% [markdown]
# ## Common escape sequences

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Title:\t\tPython Programming\nQuantity:\t5")
# Out:
# Title:		Python Programming
# Quantity:	5

# %%
print("C:\\murach\\python")
# Out:
# C:\murach\python

# %% [markdown]
# ## Four ways to include quotation marks in a string

# %%
"Type \"x\" to exit"  # String is: Type "x" to exit.
# Out:
# 'Type "x" to exit'

# %%
'Type \'x\' to exit'  # String is: Type 'x' to exit.
# Out:
# "Type 'x' to exit"

# %%
"Type 'x' to exit"    # String is: Type 'x' to exit.
# Out:
# "Type 'x' to exit"

# %%
'Type "x" to exit'    # String is: Type "x" to exit.
# Out:
# 'Type "x" to exit'

# %%
print("Total Score: " 
      + str(score_total)
      + "\nAverage Score: "
      + str(average_score))
# Out:
# Total Score: 150
# Average Score: 40

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(19.99)
# Out:
# 19.99

# %%
print("Price:", 19.99)
# Out:
# Price: 19.99

# %%
print(1, 2, 3, 4)
# Out:
# 1 2 3 4

# %%
print("Total Score:", score_total,
      "\nAverage Score:", average_score)
# Out:
# Total Score: 150
# Average Score: 40

# %%
print("Total Score: " + str(score_total) +
     "\nAverage Score: " + str(average_score))
# Out:
# Total Score: 150
# Average Score: 40

# %% [markdown]
# ## The input() function

# %%
first_name = input("Enter your first name: ")
# Out:
# Enter your first name:

# %%
print("Hello, " + first_name + "!")
# Out:
# Hello, !

# %% [markdown]
# ## Another way to get input from the user

# %%
print("What is your first name?")
first_name = input()
print("Hello, " + first_name + "!")
# Out:
# What is your first name?
#
# Hello, !

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 15
y = "5"
z = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-c8982628e25e> in <module>
#       1 x = 15
#       2 y = "5"
# ----> 3 z = x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 15
y = "5"
z = x + int(y)

# %%
z

# %% [markdown]
# ## Code that gets an int value from the user

# %%
quantity = input("Enter the quantity: ")	# get str type
quantity = int(quantity)           # convert to int type
# Out:
# Enter the quantity:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-099dd799f5e4> in <module>
#       1 quantity = input("Enter the quantity: ")        # get str type
# ----> 2 quantity = int(quantity)           # convert to int type
#
# ValueError: invalid literal for int() with base 10: ''

# %%
quantity
# Out:
# ''

# %% [markdown]
# ## How to use chaining to get the value in one statement

# %%
quantity = int(input("Enter the quantity: "))
# Out:
# Enter the quantity:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-c939d9cad262> in <module>
# ----> 1 quantity = int(input("Enter the quantity: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
quantity
# Out:
# ''

# %%
price = float(input("Enter the price: "))
# Out:
# Enter the price:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-35b15130ab31> in <module>
# ----> 1 price = float(input("Enter the price: "))
#
# ValueError: could not convert string to float:

# %%
miles_driven = 150
gallons_used = 5.875
mpg = miles_driven / gallons_used  # 25.53191489361702
mpg = round(mpg, 2)                # 25.53

# %%
mpg = round(miles_driven / gallons_used, 2)

# %%
mpg
# Out:
# 25.53
